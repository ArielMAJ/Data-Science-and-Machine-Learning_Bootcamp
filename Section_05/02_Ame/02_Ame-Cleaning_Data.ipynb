# %%
from sklearn.datasets import fetch_openml
import pandas as pd
import numpy as np

np.set_printoptions(linewidth=150)

# %%
ame_data = fetch_openml(name="house_prices", as_frame=True)

# %% [markdown]
# # Data "exploration" with Pandas

# %%
ame_data.feature_names
# Out:
# ['Id',
#  'MSSubClass',
#  'MSZoning',
#  'LotFrontage',
#  'LotArea',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'MasVnrArea',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Functional',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
# ...

# %%
# Price in thousands (000s)
ame_data.target
# Out:
# 0       208500.0
# 1       181500.0
# 2       223500.0
# 3       140000.0
# 4       250000.0
#           ...
# 1455    175000.0
# 1456    210000.0
# 1457    266500.0
# 1458    142125.0
# 1459    147500.0
# Name: SalePrice, Length: 1460, dtype: float64

# %%
data = pd.DataFrame(data=ame_data.data, columns=ame_data.feature_names)

data['PRICE'] = ame_data.target

# %%
data.head()
# Out:
#     Id  MSSubClass MSZoning  ...  SaleType  SaleCondition     PRICE
# 0  1.0        60.0       RL  ...        WD         Normal  208500.0
# 1  2.0        20.0       RL  ...        WD         Normal  181500.0
# 2  3.0        60.0       RL  ...        WD         Normal  223500.0
# 3  4.0        70.0       RL  ...        WD        Abnorml  140000.0
# 4  5.0        60.0       RL  ...        WD         Normal  250000.0
#
# [5 rows x 81 columns]

# %%
data.tail()
# Out:
#           Id  MSSubClass MSZoning  ...  SaleType  SaleCondition     PRICE
# 1455  1456.0        60.0       RL  ...        WD         Normal  175000.0
# 1456  1457.0        20.0       RL  ...        WD         Normal  210000.0
# 1457  1458.0        70.0       RL  ...        WD         Normal  266500.0
# 1458  1459.0        20.0       RL  ...        WD         Normal  142125.0
# 1459  1460.0        20.0       RL  ...        WD         Normal  147500.0
#
# [5 rows x 81 columns]

# %%
data.count()
# Out:
# Id               1460
# MSSubClass       1460
# MSZoning         1460
# LotFrontage      1201
# LotArea          1460
#                  ...
# MoSold           1460
# YrSold           1460
# SaleType         1460
# SaleCondition    1460
# PRICE            1460
# Length: 81, dtype: int64

# %% [markdown]
# # Cleaning Data - Checking for missing values

# %%
pd.isnull(data).any()
# Out:
# Id               False
# MSSubClass       False
# MSZoning         False
# LotFrontage       True
# LotArea          False
#                  ...
# MoSold           False
# YrSold           False
# SaleType         False
# SaleCondition    False
# PRICE            False
# Length: 81, dtype: bool

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   float64
#  1   MSSubClass     1460 non-null   float64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   float64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# In this specific dataset there are a few null values, but they may be irrelevant to our analysis (as the columns we're using don't have missing values).
