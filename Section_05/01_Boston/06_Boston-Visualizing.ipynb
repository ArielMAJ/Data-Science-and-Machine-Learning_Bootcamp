# %% [markdown]
# ## Imports and loading data
# Loading the boston dataset directly from its "[source](http://lib.stat.cmu.edu/datasets/boston)".

# %%
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np
import seaborn as sns

# %matplotlib inline

# %%
import urllib
data_url = "http://lib.stat.cmu.edu/datasets/boston"

raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
target = raw_df.values[1::2, 2]

file = urllib.request.urlopen(data_url)
columns = list(map(lambda x: x.split(' ')[1], [line.decode('utf-8') for line in file][7:20]))
data = pd.DataFrame(data=data, columns=columns)
data["PRICE"] = target

# %% [markdown]
# ## More Visualizing

# %%
sns.set()
sns.set_context('notebook')
sns.set_style('whitegrid')
# plt.figure(figsize=(8,4), dpi=200)
sns.jointplot(x=data['TAX'],y=data['RAD'], color='darkcyan', kind='reg')

plt.show()

# %%
data.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'PRICE'],
#       dtype='object')

# %%
sns.set()
sns.set_context('notebook')
sns.set_style('whitegrid')
# plt.figure(figsize=(8,4), dpi=200)
sns.jointplot(x=data['RM'],y=data['PRICE'], color='darkcyan', kind='reg')

plt.show()

# %%
# %%time

sns.pairplot(data)
plt.show()
# Out:
# Wall time: 40.9 s

# %%
# %%time

sns.pairplot(data, kind='reg', plot_kws={'line_kws': {'color': 'cyan'}})
plt.savefig('pairplot_regression.png',dpi=500)
plt.show()
# Out:
# Wall time: 2min 4s
