# %%
from IPython.display import clear_output as clear
from sklearn.datasets import load_boston
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %matplotlib inline

# %%
boston_data = load_boston()
data = pd.DataFrame(data=boston_data.data, columns=boston_data.feature_names)
data["PRICE"] = boston_data.target
clear()

# %% [markdown]
# # Visualising Data - Histograms, Distributions and Bar Charts

# %% [markdown]
# Color pallete: https://colorhunt.co/palette/e7e0c9c1cfc06b7aa111324d

# %%
# plt.rcParams['text.color'] = plt.rcParams['axes.labelcolor'] = plt.rcParams['xtick.color'] = plt.rcParams['ytick.color'] = "#11324D"
plt.rcParams.update({
    'text.color' : "#11324D",
    'axes.labelcolor' : "#11324D",
    'xtick.color' : "#11324D",
    'ytick.color' : "#11324D"
})

# %%
fig = plt.figure(figsize=(5, 3), facecolor='#E7E0C9', dpi=200)
# fig.set_facecolor(color='#E7E0C9')

ax = plt.axes()
for spine in ax.spines:
    ax.spines[spine].set_color("#11324D")
ax.set_facecolor(color='#C1CFC0')


plt.hist(data["PRICE"], bins=50, ec="#11324D", color="#6B7AA1")
plt.xlabel("Price (in thousands)")
plt.ylabel("Frequency")

plt.show()

# %%
fig = plt.figure(figsize=(8, 3), dpi=200, facecolor='#E7E0C9')

ax = fig.add_subplot(1, 2, 1)
for spine in ax.spines:
    ax.spines[spine].set_color("#11324D")
ax.set_facecolor(color='#C1CFC0')

# sns.distplot(data['PRICE'], bins=50, color="#6B7AA1", kde=True)
sns.distplot(
    data['PRICE'],
    bins=50,
    color="#6B7AA1",
    kde=False,
    hist_kws=dict(edgecolor='black', linewidth=0.5, alpha=1) # Adds an outline to the histogram to improve readability
)


ax = fig.add_subplot(1, 2, 2)
for spine in ax.spines:
    ax.spines[spine].set_color("#11324D")
ax.set_facecolor(color='#C1CFC0')

sns.histplot(data['PRICE'], bins=50, color="#6B7AA1", kde=False) #hist=False, kde=False


plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
fig = plt.figure(figsize=(8, 3), dpi=200, facecolor='#E7E0C9')

ax = fig.add_subplot(1, 2, 1)
for spine in ax.spines:
    ax.spines[spine].set_color("#11324D")
ax.set_facecolor(color='#C1CFC0')

sns.distplot(data['PRICE'], bins=50, color="#6B7AA1", kde=True) #hist=False, kde=False


ax = fig.add_subplot(1, 2, 2)
for spine in ax.spines:
    ax.spines[spine].set_color("#11324D")
ax.set_facecolor(color='#C1CFC0')

sns.histplot(data['PRICE'], bins=50, color="#6B7AA1", kde=True) #hist=False, kde=False


plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Color pallete: https://colorhunt.co/palette/e7e0c9c1cfc06b7aa111324d

def paint_my(ax):
    for spine in ax.spines:
        ax.spines[spine].set_color("#11324D")
    ax.set_facecolor(color='#C1CFC0')

fig = plt.figure(figsize=(10, 3), facecolor='#E7E0C9', dpi=200)
# fig.set_facecolor(color='#E7E0C9')

ax = fig.add_subplot(1, 2, 1)
paint_my(ax)

plt.hist(data["RM"], ec="#11324D", color="#6B7AA1")
plt.xlabel("Rooms per dwelling")
plt.ylabel("Frequency")


ax = fig.add_subplot(1, 2, 2)
paint_my(ax)

plt.hist(data["RM"], bins=30, ec="#11324D", color="#6B7AA1")
plt.xlabel("Rooms per dwelling")
plt.ylabel("Frequency")


plt.show()

# %%
print(
    f"Min:\t{data['RM'].min():.3f}",
    f"Mean:\t{data['RM'].mean():.3f}",
    f"Max:\t{data['RM'].max():.3f}",
    sep='\n'
)
# Out:
# Min:	3.561
# Mean:	6.285
# Max:	8.780

# %% [markdown]
# # Just and example of how to access, edit and display figures already drawn in different cells

# %%
fig.axes[0].set_facecolor(color='green')
fig.axes[1].set_facecolor(color='lightgreen')
display(fig)
